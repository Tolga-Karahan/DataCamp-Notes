# %%
import pandas as pd

data = {'weekday':['Sun', 'Sun', 'Mon', 'Mon'],
        'city':['Austin', 'Dallas', 'Austin', 'Dallas'],
        'bread':[139, 237, 326, 456],
        'butter':[20, 45, 70, 98]}

df = pd.DataFrame(data)
df
# Out:
#   weekday    city  bread  butter
# 0     Sun  Austin    139      20
# 1     Sun  Dallas    237      45
# 2     Mon  Austin    326      70
# 3     Mon  Dallas    456      98

# %%
# Örneğin herhangi bir gün için girdilerin sayısını öğrenmek istediğimizde mask işlemi yapıyorduk.
# Bunun yerine groupby da kullanabiliriz.

# %%
count1 = df[df['weekday'] == 'Sun'].count()
print(count1)

counts = df.groupby('weekday').count()
print(counts)
print(type(counts))
# Out:
# weekday    2
# city       2
# bread      2
# butter     2
# dtype: int64
#          city  bread  butter
# weekday
# Mon         2      2       2
# Sun         2      2       2
# <class 'pandas.core.frame.DataFrame'>

# %%
# groupby metodu çağırıldığında pandas.core.groupby.DataFrameGroupBy tipinde bir nesne döndürür.
# Bu nesnenin içinde her bir grubun anahtar olduğu group sözlüğü bulunur.

# %%
gb = df.groupby('weekday')
print(type(gb))
print(gb.groups.keys())
# Out:
# <class 'pandas.core.groupby.groupby.DataFrameGroupBy'>
# dict_keys(['Mon', 'Sun'])

# %%
# groups sözlüğünü kullanarak her bir grup üzerinde iterasyon yapabiliriz.
# Bu sayede her bir grubu iteratif olarak filtreleyebiliriz.

# %%
for group_name, group in gb:
    avg = group['butter'].mean()
    print(group_name, avg)
# Out:
# Mon 84.0
# Sun 32.5

# %%
# Örnek

for group_name, group in splitting:
    avg = group.loc[group['name'].str.contains('chevrolet'), 'mpg'].mean()
    print(group_name, avg)

# %%
# groupby sonucu bir dataframe olduğundan slicing yapabiliriz.

# %%
print(df.groupby('weekday').count()[['bread']])
# Out:
#          bread
# weekday
# Mon          2
# Sun          2

# %%
# Toplamıda elde etmek isteyebiliriz.

# %%
print('Sum is: ', df.groupby('weekday')['bread'].sum())
# Out:
# Sum is:  weekday
# Mon    782
# Sun    376
# Name: bread, dtype: int64

# %%
print(df.groupby('weekday')[['bread', 'butter']].sum())
# Out:
#          bread  butter
# weekday
# Mon        782     168
# Sun        376      65

# %%
# groupby metoduna birden fazla sütun geçirerek multi-level groupby yapabiliriz.

# %%
df.groupby(['city', 'weekday']).mean()
# Out:
#                 bread  butter
# city   weekday
# Austin Mon        326      70
#        Sun        139      20
# Dallas Mon        456      98
#        Sun        237      45

# %%
# İndeksler aynı olduğunda başa bir dataframe ve ya series kullanarakta gruplama yapabiliriz.
# Örneğin müşterileri belirten aşağıdaki gibi bir Series olsun. Bu Series i kullanarak tabloyu
# müşterilere göre gruplayabiliriz ve her müşteri için toplamlara bakabiliriz.

# %%
customers = pd.Series(['Dave', 'Alice', 'Bob', 'Alice'])
df.groupby(customers).sum()
# Out:
#        bread  butter
# Alice    693     143
# Bob      326      70
# Dave     139      20

# %%
# Aynı mantığı kullanarak ayrı ayrı sütunları da gruplayıp aggegation yapabiliriz.

# %%
df.groupby(customers)[['bread']].sum()
# Out:
#        bread
# Alice    693
# Bob      326
# Dave     139

# %%
# Bir sütundaki farklı(distinct) değerleri unique metodu ile görebiliriz. value_counts metodu ise
# her bir farklı değerden kaç tane olduğunu verir.

# %%
print(df['city'].unique())
print(df['city'].value_counts())
# Out:
# ['Austin' 'Dallas']
# Austin    2
# Dallas    2
# Name: city, dtype: int64

# %%
# Kategorik değerler içeren sütunları stringten category tipine çevirerek bellekten tasarruf sağlarız.
# Ayrıca bu sayede groupby gibi işlemler çok daha hızlı yapılır.

# %%
df.info()
df.city = df.city.astype('category')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# weekday    4 non-null object
# city       4 non-null object
# bread      4 non-null int64
# butter     4 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 208.0+ bytes

# %%
# Gruplamak için başka bir dataframe e ait sütunun kullanılmasına başka bir örnek aşağıdaki gibidir.
# Ortalama yaşam süresini tutan bir dataframe ve bölgeleri tutan bir datafame var.
# Her ikiside ülkelere göre indekslendiği için bölgeleri tutan dataframein region sütununu kullanarak
# ortalama yaşam süresini tutan dataframe i bölgelere göre gruplayabiliyoruz.

# %%
# Read life_fname into a DataFrame: life
life = pd.read_csv(life_fname, index_col='Country')

# Read regions_fname into a DataFrame: regions
regions = pd.read_csv(regions_fname, index_col='Country')

# Group life by regions['region']: life_by_region
life_by_region = life.groupby(regions['region'])

# Print the mean over the '2010' column of life_by_region
print(life_by_region['2010'].mean())

# %%
# Birden fazla aggregation fonksiyonu da kullanabiliriz. Sonuç olarak multi-level sütun indekslerine
# sahip bir dataframe elde ederiz.

# %%
df.groupby('city').agg(['mean', 'median'])
# Out:
#         bread        butter
#          mean median   mean median
# city
# Austin  232.5  232.5   45.0   45.0
# Dallas  346.5  346.5   71.5   71.5

# %%
# Kendi tanımladığımız aggregation fonksiyonlarınıda kullanabiliriz
# Out:
# 0    NaN
# 1    1.0
# 2    3.0
# dtype: float64

# %%
def data_range(series):
    return series.max() - series.min()

df.groupby('city').agg(data_range)
# Out:
#         bread  butter
# city
# Austin    187      50
# Dallas    219      53

# %%
# Aggregation fonksiyonlarını bir sözlük olarakta geçirebiliriz. Böylece her bir sütuna uygulanacak
# aggregation fonksiyonunu ayrı ayrı tanımlayabiliriz.

# %%
df.groupby('city').agg({'bread':sum, 'butter':data_range})
# Out:
#         bread  butter
# city
# Austin    465      50
# Dallas    693      53

# %%
# Örnek

# Read the CSV file into a DataFrame and sort the index: gapminder
gapminder = pd.read_csv('gapminder.csv', index_col=['Year', 'region', 'Country']).sort_index()

# Group gapminder by 'Year' and 'region': by_year_region
by_year_region = gapminder.groupby(level=['Year', 'region'])

# Define the function to compute spread: spread
def spread(series):
    return series.max() - series.min()

# Create the dictionary: aggregator
aggregator = {'population':'sum', 'child_mortality':'mean', 'gdp':spread}

# Aggregate by_year_region using the dictionary: aggregated
aggregated = by_year_region.agg(aggregator)

# Print the last 6 entries of aggregated 
print(aggregated.tail(6))

# %%
# İndeks datetime tipinde ise tarih içerisinden herhangi bir zaman bilgisine göre gruplama 
# yapabiliriz. Örneğin güne göre gruplama aşağıdaki gibi yapılabilir:

# Read file: sales
sales = pd.read_csv('sales.csv', index_col='Date', parse_dates=True)

# Create a groupby object: by_day
by_day = sales.groupby(sales.index.strftime('%a'))

# Create sum: units_sum
units_sum = by_day.agg(sum)

# Print units_sum
print(units_sum)

# %%
# Gruplama yapıldıktan sonra bir aggregation fonksiyonu uygulamak yerine verileri dönüştürmek isteyebiliriz.
# Böylece indeks değiştirilmeksizin tablodaki veriler dönüştürülür. Bazen istatistikleri gruplar içerisinde
# hesaplamak daha tutarlı sonuçlar verebilir. Gruplar üzerinde dönüşüm yapmak için transform metodunu
# kullanırız. Dolayısıyla bu yöntem kayıp değerlerin imputasyonu içinde kullanılabilir.

# %%
titanic_df = pd.read_csv('titanic.csv')
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.2+ KB

# %%
def impute_by_median(series):
    series.fillna(series.median())
    
by_sex_class = df.groupby(['sex', 'pclass'])
titanic_df.age = by_sex_class.age.transform(impute_by_median)
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          0 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.2+ KB

# %%
# Gruplar üzerinden daha karmaşık işlemler için apply metodu kullanılabilir.

# %%
gapminder_df = pd.read_csv('gapminder_tidy.csv')
gapminder_df = gapminder_df.groupby(['region', 'Country']).mean().reset_index().set_index('Country').sort_index()
gapminder_df
# Out:
#                                             region    Year  fertility  \
# Country
# Afghanistan                             South Asia  1988.5   7.359780
# Albania                      Europe & Central Asia  1988.5   3.290100
# Algeria                 Middle East & North Africa  1988.5   5.065340
# Angola                          Sub-Saharan Africa  1988.5   6.988800
# Antigua and Barbuda                        America  1988.5   2.528700
# Argentina                                  America  1988.5   2.843160
# Armenia                      Europe & Central Asia  1988.5   2.303440
# Aruba                                      America  1988.5   2.315780
# Australia                      East Asia & Pacific  1988.5   2.076340
# Austria                      Europe & Central Asia  1988.5   1.680700
# Azerbaijan                   Europe & Central Asia  1988.5   3.096920
# Bahamas                                    America  1988.5   2.717200
# Bahrain                 Middle East & North Africa  1988.5   4.165860
# Bangladesh                              South Asia  1988.5   4.786820
# Barbados                                   America  1988.5   2.173640
# Belarus                      Europe & Central Asia  1988.5   1.832080
# Belgium                      Europe & Central Asia  1988.5   1.806040
# Belize                                     America  1988.5   4.721960
# Benin                           Sub-Saharan Africa  1988.5   6.360200
# Bhutan                                  South Asia  1988.5   5.100800
# Bolivia                                    America  1988.5   5.002180
# Bosnia and Herzegovina       Europe & Central Asia  1988.5   1.942440
# Botswana                        Sub-Saharan Africa  1988.5   4.865180
# Brazil                                     America  1988.5   3.360060
# Brunei                         East Asia & Pacific  1988.5   3.745760
# Bulgaria                     Europe & Central Asia  1988.5   1.758300
# Burkina Faso                    Sub-Saharan Africa  1988.5   6.660320
# Burundi                         Sub-Saharan Africa  1988.5   7.158940
# Cambodia                       East Asia & Pacific  1988.5   5.023000
# Cameroon                        Sub-Saharan Africa  1988.5   6.003200
# ...                                            ...     ...        ...
# Syria                   Middle East & North Africa  1988.5   5.537880
# Taiwan                         East Asia & Pacific  1988.5   2.292390
# Tajikistan                   Europe & Central Asia  1988.5   5.155220
# Tanzania                        Sub-Saharan Africa  1988.5   6.195760
# Thailand                       East Asia & Pacific  1988.5   2.985460
# Timor-Leste                    East Asia & Pacific  1988.5   5.886420
# Togo                            Sub-Saharan Africa  1988.5   6.194600
# Tokelau                        East Asia & Pacific  2006.0        NaN
# Tonga                          East Asia & Pacific  1988.5   4.973400
# Trinidad and Tobago                        America  1988.5   2.680460
# Tunisia                 Middle East & North Africa  1988.5   4.053500
# Turkey                       Europe & Central Asia  1988.5   3.636800
# Turkmenistan                 Europe & Central Asia  1988.5   4.322080
# Uganda                          Sub-Saharan Africa  1988.5   6.896080
# Ukraine                      Europe & Central Asia  1988.5   1.714680
# United Arab Emirates    Middle East & North Africa  1988.5   4.336940
# United Kingdom               Europe & Central Asia  1988.5   1.913140
# United States                              America  1988.5   2.050362
# Uruguay                                    America  1988.5   2.520660
# Uzbekistan                   Europe & Central Asia  1988.5   4.326900
# Vanuatu                        East Asia & Pacific  1988.5   5.039140
# Venezuela                                  America  1988.5   3.805300
# Vietnam                        East Asia & Pacific  1988.5   3.914740
# Virgin Islands (U.S.)                      America  1988.5   3.266100
# West Bank and Gaza      Middle East & North Africa  1988.5   6.383540
# Western Sahara          Middle East & North Africa  1988.5   4.545980
# Yemen, Rep.             Middle East & North Africa  1988.5   7.303940
# Zambia                          Sub-Saharan Africa  1988.5   6.633800
# Zimbabwe                        Sub-Saharan Africa  1988.5   5.608020
# Åland                        Europe & Central Asia  2001.5        NaN
#
#                             life    population  child_mortality       gdp
# Country
# Afghanistan             47.35280  1.827204e+07       203.198000   1187.20
# Albania                 71.64512  2.817009e+06        57.443400   5012.52
# Algeria                 62.26872  2.402512e+07       106.082000   9662.18
# Angola                  42.32716  1.098218e+07       229.667800   4719.16
# Antigua and Barbuda     70.63692  7.185468e+04        30.917800  13765.38
# Argentina               71.09126  3.183379e+07        36.136600  11058.80
# Armenia                 70.71564  3.018367e+06        50.982600   3975.92
# Aruba                   72.48278  7.518588e+04        21.334706  25756.80
# Australia               76.60392  1.680300e+07        11.452000  28633.94
# Austria                 75.23108  7.790339e+06        13.874000  29908.06
# Azerbaijan              66.17774  7.016893e+06        79.652200   8106.30
# Bahamas                 70.11278  2.484314e+05        24.242400  22340.84
# Bahrain                 70.55164  5.355240e+05        35.432000  38040.68
# Bangladesh              58.77894  1.029884e+08       147.172000   1465.10
# Barbados                70.12256  2.565209e+05        26.608000  12174.96
# Belarus                 70.75740  9.687342e+06        18.084400   8078.16
# Belgium                 75.40132  1.001560e+07        12.470000  29497.82
# Belize                  69.60422  1.972458e+05        52.548800   5174.10
# Benin                   50.81212  5.127087e+06       189.444000   1401.20
# Bhutan                  51.30348  4.983366e+05       154.125200   2686.74
# Bolivia                 56.47150  6.693500e+06       138.122000   4173.20
# Bosnia and Herzegovina  70.46810  3.769177e+06        33.758800   4497.22
# Botswana                55.31484  1.320157e+06        80.030000   7164.60
# Brazil                  65.73666  1.437451e+08        72.212000  10235.46
# Brunei                  72.64074  2.486730e+05        25.733600  81800.12
# Bulgaria                71.58232  8.348327e+06        25.916000  10143.30
# Burkina Faso            47.43212  9.855631e+06       220.736000    948.16
# Burundi                 47.53324  5.426705e+06       182.528000    813.80
# Cambodia                50.64884  9.701979e+06       147.623400   1422.46
# Cameroon                50.96252  1.224000e+07       162.534000   2545.32
# ...                          ...           ...              ...       ...
# Syria                   67.90648  1.234785e+07        52.960000   4573.16
# Taiwan                  73.37640  1.924960e+07              NaN  20577.26
# Tajikistan              62.85910  4.897108e+06       113.464000   3167.90
# Tanzania                50.86756  2.627975e+07       155.358000   1562.92
# Thailand                67.24946  5.345732e+07        50.666000   6489.20
# Timor-Leste             48.58008  7.761281e+05       190.741400   1123.30
# Togo                    52.33336  3.696634e+06       157.480000   1494.86
# Tokelau                 69.00000  1.170000e+03              NaN       NaN
# Tonga                   68.68152  9.347144e+04        29.426000   3414.52
# Trinidad and Tobago     67.47936  1.164284e+06        36.002000  17142.58
# Tunisia                 65.05156  7.748863e+06        84.434000   5939.38
# Turkey                  63.04974  5.269290e+07        96.362000  10771.66
# Turkmenistan            61.92726  3.553021e+06        99.369000   8452.20
# Uganda                  49.81892  1.864524e+07       161.184000   1018.44
# Ukraine                 69.47000  4.866075e+07        23.627000   7901.70
# United Arab Emirates    69.55666  2.366729e+06        39.482000  96394.10
# United Kingdom          75.66216  5.772785e+07        11.832000  25907.72
# United States           74.85982  2.533126e+08        13.712000  36198.92
# Uruguay                 72.34602  3.075055e+06        31.382000  10867.64
# Uzbekistan              65.77166  1.956807e+07        92.839000   3176.80
# Vanuatu                 61.68064  1.494389e+05        57.638000   2374.50
# Venezuela               69.73914  1.908535e+07        36.852000  15748.50
# Vietnam                 68.94694  6.504572e+07        55.030000   2086.90
# Virgin Islands (U.S.)   73.70928  9.520466e+04        17.085000       NaN
# West Bank and Gaza      65.33600  2.304277e+06        66.981400   2710.20
# Western Sahara          54.91502  2.414180e+05        96.474412       NaN
# Yemen, Rep.             53.65530  1.300170e+07              NaN       NaN
# Zambia                  47.73318  7.893245e+06       153.464000   2990.06
# Zimbabwe                53.96624  9.362832e+06        94.108000   2233.76
# Åland                   80.13900  2.637243e+04              NaN       NaN
#
# [204 rows x 7 columns]

# %%
def disparity(group):
    regional_gdp = group['gdp'].max() - group['gdp'].min()
    z_gdp = (group['gdp'] - group['gdp'].mean()) / group['gdp'].std()
    return pd.DataFrame({'z(gdp)':z_gdp, 'regional_spread(gdp)':regional_gdp})

gapminder_by_region = gapminder_df.groupby('region')
gdp = gapminder_by_region.apply(disparity)
gdp.head()
print(gdp.loc[['Turkey', 'Greece', 'United States', 'China']])
# Out:
#                  z(gdp)  regional_spread(gdp)
# Country
# Turkey        -0.659508              52736.80
# Greece         0.173024              52736.80
# United States  3.006848              34186.46
# China         -0.559400              80676.82

# %%
data = {'A':[1, 2, 3], 'B':[3, 4, 5], 'C':['D', 'E', 'D'], 'F':['G', 'H', 'I']}
df = pd.DataFrame(data)
print(df, '\n')
print(df.groupby(['C', 'F']).mean(), '\n')
print(df.groupby(['F', 'C']).mean(), '\n')
# Out:
#    A  B  C  F
# 0  1  3  D  G
# 1  2  4  E  H
# 2  3  5  D  I
#
#      A  B
# C F
# D G  1  3
#   I  3  5
# E H  2  4
#
#      A  B
# F C
# G D  1  3
# H E  2  4
# I D  3  5

# %%
# Boolean serileri kullanarak one-to-all karşılaştırmalar yapabiliriz. Yani aradığımız koşula uyan
# ve uymayan tüm satırlar için gruplama yapılır. Aşağıda Austin ve diğer şehirlerdeki ekmek tüketimi
# karşılaştırılmıştır.

# %%
mask = df['city'] == 'Austin'
print(df.groupby(['weekday', mask])['bread'].mean())
# Out:
# weekday  city
# Mon      False    456
#          True     326
# Sun      False    237
#          True     139
# Name: bread, dtype: int64

# %%
# apply metodunu kullanarak her bir grubu teker teker işleyebiliriz. Bu sayede her bir grup üzerinde
# filtreleme işlemide yapabiliriz.

# %%
def c_deck_survival(group):
    c_passengers = group['cabin'].str.startswith('C').fillna(False)
    return group.loc[c_passengers, 'survived'].mean()

by_sex = titanic_df.groupby('sex')
c_surv_by_sex = by_sex.apply(c_deck_survival)
print(c_surv_by_sex)
# Out:
# sex
# female    0.913043
# male      0.312500
# dtype: float64

# %%
# filter fonksiyonunu kullanarakta filteleme yapabiliriz. Aşağıdaki örnekte sales verisini okuduk ve
# şirketlere göre grupladık. Ardından Units sütunu üzerinde 35 ve daha az girdisi olan şirketlere ait
# tüm satırları filtreledik.
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: survived, dtype: int64

# %%
sales_df = pd.read_csv('./sales/sales-feb-2015.csv', index_col='Date', parse_dates=True)
print(sales_df, '\n')

by_company = sales_df.groupby('Company')

# Print sum of units purchased by companies for verification
print(by_company['Units'].sum(), '\n')

# Filter companies which purchases less than or equal to 35
print(by_company.filter(lambda g:g['Units'].sum() > 35))
# Out:
#                              Company   Product  Units
# Date
# 2015-02-02 08:30:00            Hooli  Software      3
# 2015-02-02 21:00:00        Mediacore  Hardware      9
# 2015-02-03 14:00:00          Initech  Software     13
# 2015-02-04 15:30:00        Streeplex  Software     13
# 2015-02-04 22:00:00  Acme Coporation  Hardware     14
# 2015-02-05 02:00:00  Acme Coporation  Software     19
# 2015-02-05 22:00:00            Hooli   Service     10
# 2015-02-07 23:00:00  Acme Coporation  Hardware      1
# 2015-02-09 09:00:00        Streeplex   Service     19
# 2015-02-09 13:00:00        Mediacore  Software      7
# 2015-02-11 20:00:00          Initech  Software      7
# 2015-02-11 23:00:00            Hooli  Software      4
# 2015-02-16 12:00:00            Hooli  Software     10
# 2015-02-19 11:00:00        Mediacore  Hardware     16
# 2015-02-19 16:00:00        Mediacore   Service     10
# 2015-02-21 05:00:00        Mediacore  Software      3
# 2015-02-21 20:30:00            Hooli  Hardware      3
# 2015-02-25 00:30:00          Initech   Service     10
# 2015-02-26 09:00:00        Streeplex   Service      4
#
# Company
# Acme Coporation    34
# Hooli              30
# Initech            30
# Mediacore          45
# Streeplex          36
# Name: Units, dtype: int64
#
#                        Company   Product  Units
# Date
# 2015-02-02 21:00:00  Mediacore  Hardware      9
# 2015-02-04 15:30:00  Streeplex  Software     13
# 2015-02-09 09:00:00  Streeplex   Service     19
# 2015-02-09 13:00:00  Mediacore  Software      7
# 2015-02-19 11:00:00  Mediacore  Hardware     16
# 2015-02-19 16:00:00  Mediacore   Service     10
# 2015-02-21 05:00:00  Mediacore  Software      3
# 2015-02-26 09:00:00  Streeplex   Service      4

# %%
# map metodunu kullanarak maskelerdeki değerleri yeni değerlere atayabilir. Bunu herhangi bir series
# içinde yapabiliriz. Örneğin 10 yaş altı ve üstü insanlara göre gruplama yapabiliriz. Ayrıca sınıf 
# üzerinden de gruplama yaparak çok seviyeli indeks kullanarak olasılıklara bakabiliriz.
# Out:
#    A   E
# 0  B  10
# 1  B  12
# 2  C   3
# 3  D   4
# 4  F  54
#
#    A   E
# 0  B  10
# 1  B  12
# 4  F  54

# %%
under10 = (titanic_df['age'] < 10).map({True:'under 10', False:'over 10'})
print(titanic_df.groupby([under10, 'pclass'])['survived'].mean())
# Out:
# age       pclass
# over 10   1         0.617555
#           2         0.380392
#           3         0.238897
# under 10  1         0.750000
#           2         1.000000
#           3         0.446429
# Name: survived, dtype: float64
