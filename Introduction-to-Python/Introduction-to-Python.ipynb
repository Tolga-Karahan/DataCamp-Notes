# %%
"""
Bir fonksiyon cagrisi yaparken opsiyonel argumanlarin sadece bir kacina deger vermek istiyorsak, deger vermek
istedigimiz argumanlara fonksiyon cagrisi icerisinde = kullanarak deger veririz. Boylece sadece esittir kullandigimiz
argumanlara deger gecirilir diger opsiyonel argumanlar icin ise varsayilan degerler kullanilir.
"""
my_list = [7, 3, 5]
sorted(my_list, reverse=True)
# Out:
# [7, 5, 3]
